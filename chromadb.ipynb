# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl.metadata (5.1 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: pydantic>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (2.12.4)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (2.6.1)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (2.4.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (4.15.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.27.0-cp313-cp313-win_amd64.whl.metadata (5.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.43.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.43.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.43.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl.metadata (10 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (7.4.0)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (0.20.0)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-36.0.2-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\hp\anaconda3\lib\site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: packaging>=24.0 in c:\users\hp\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (4.7.0)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\hp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\hp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting pyyaml>=6.0.0 (from chromadb)
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\hp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\hp\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting aiohttp<4.0.0,>=3.13.5 (from kubernetes>=28.1.0->chromadb)
#   Downloading aiohttp-3.14.1-cp313-cp313-win_amd64.whl.metadata (8.5 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.18.0)
# Requirement already satisfied: flatbuffers in c:\users\hp\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\users\hp\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (7.34.1)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.75.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.43.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.43.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.43.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.43.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.64b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.64b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hp\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hp\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hp\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\hp\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb) (1.2.3)
# Requirement already satisfied: filelock in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: typer-slim in c:\users\hp\anaconda3\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.20.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\hp\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl.metadata (3.7 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.2.0-cp313-cp313-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in c:\users\hp\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.3.2)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Downloading chromadb-1.5.9-cp39-abi3-win_amd64.whl (23.5 MB)
#    ---------------------------------------- 0.0/23.5 MB ? eta -:--:--
#    -- ------------------------------------- 1.6/23.5 MB 9.9 MB/s eta 0:00:03
#    ------- -------------------------------- 4.2/23.5 MB 11.0 MB/s eta 0:00:02
#    ------------ --------------------------- 7.1/23.5 MB 11.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 10.2/23.5 MB 12.8 MB/s eta 0:00:02
#    --------------------- ------------------ 12.8/23.5 MB 13.4 MB/s eta 0:00:01
#    -------------------------- ------------- 15.7/23.5 MB 12.9 MB/s eta 0:00:01
#    -------------------------------- ------- 19.4/23.5 MB 13.5 MB/s eta 0:00:01
#    ------------------------------------- -- 22.0/23.5 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 23.5/23.5 MB 12.8 MB/s eta 0:00:00
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Downloading kubernetes-36.0.2-py2.py3-none-any.whl (4.6 MB)
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    ---------------------------------------- 4.6/4.6 MB 20.8 MB/s eta 0:00:00
# Downloading aiohttp-3.14.1-cp313-cp313-win_amd64.whl (479 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.1-cp313-cp313-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.27.0-cp313-cp313-win_amd64.whl (13.4 MB)
#    ---------------------------------------- 0.0/13.4 MB ? eta -:--:--
#    ---------- ----------------------------- 3.7/13.4 MB 19.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.7/13.4 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------- 13.4/13.4 MB 21.6 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.43.0-py3-none-any.whl (61 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.43.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.43.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.43.0-py3-none-any.whl (72 kB)
# Downloading googleapis_common_protos-1.75.0-py3-none-any.whl (300 kB)
# Downloading opentelemetry_sdk-1.43.0-py3-none-any.whl (178 kB)
# Downloading opentelemetry_semantic_conventions-0.64b0-py3-none-any.whl (203 kB)
# Downloading pybase64-1.4.3-cp313-cp313-win_amd64.whl (35 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Downloading tokenizers-0.23.1-cp310-abi3-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 2.8/2.8 MB 18.3 MB/s eta 0:00:00
# Downloading httptools-0.8.0-cp313-cp313-win_amd64.whl (90 kB)
# Downloading watchfiles-1.2.0-cp313-cp313-win_amd64.whl (288 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: pypika, durationpy, pyyaml, pyproject_hooks, pybase64, opentelemetry-proto, opentelemetry-api, onnxruntime, oauthlib, mmh3, importlib-resources, httptools, googleapis-common-protos, aiosignal, aiohappyeyeballs, watchfiles, requests-oauthlib, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, build, aiohttp, opentelemetry-sdk, kubernetes, tokenizers, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    ----------------------------------------  0/26 [pypika]
#   Attempting uninstall: pyyaml
#    ----------------------------------------  0/26 [pypika]
#    --- ------------------------------------  2/26 [pyyaml]
#     Found existing installation: PyYAML 6.0.2
#    --- ------------------------------------  2/26 [pyyaml]
#     Uninstalling PyYAML-6.0.2:
#    --- ------------------------------------  2/26 [pyyaml]
#       Successfully uninstalled PyYAML-6.0.2
#    --- ------------------------------------  2/26 [pyyaml]
#    --- ------------------------------------  2/26 [pyyaml]
#    --- ------------------------------------  2/26 [pyyaml]
#    ------ ---------------------------------  4/26 [pybase64]
#    ------- --------------------------------  5/26 [opentelemetry-proto]
#    ------- --------------------------------  5/26 [opentelemetry-proto]
#    --------- ------------------------------  6/26 [opentelemetry-api]
#    --------- ------------------------------  6/26 [opentelemetry-api]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ---------- -----------------------------  7/26 [onnxruntime]
#    ------------ ---------------------------  8/26 [oauthlib]
#    ------------ ---------------------------  8/26 [oauthlib]
#    ------------ ---------------------------  8/26 [oauthlib]
#    ------------ ---------------------------  8/26 [oauthlib]
#    ------------ ---------------------------  8/26 [oauthlib]
#    --------------- ------------------------ 10/26 [importlib-resources]
#    --------------- ------------------------ 10/26 [importlib-resources]
#    ------------------ --------------------- 12/26 [googleapis-common-protos]
#    ------------------ --------------------- 12/26 [googleapis-common-protos]
#    ------------------ --------------------- 12/26 [googleapis-common-protos]
#    ------------------ --------------------- 12/26 [googleapis-common-protos]
#    ------------------ --------------------- 12/26 [googleapis-common-protos]
#   Attempting uninstall: aiosignal
#    ------------------ --------------------- 12/26 [googleapis-common-protos]
#     Found existing installation: aiosignal 1.2.0
#    ------------------ --------------------- 12/26 [googleapis-common-protos]
#    -------------------- ------------------- 13/26 [aiosignal]
#     Uninstalling aiosignal-1.2.0:
#    -------------------- ------------------- 13/26 [aiosignal]
#       Successfully uninstalled aiosignal-1.2.0
#    -------------------- ------------------- 13/26 [aiosignal]
#   Attempting uninstall: aiohappyeyeballs
#    -------------------- ------------------- 13/26 [aiosignal]
#     Found existing installation: aiohappyeyeballs 2.4.4
#    -------------------- ------------------- 13/26 [aiosignal]
#     Uninstalling aiohappyeyeballs-2.4.4:
#    -------------------- ------------------- 13/26 [aiosignal]
#    --------------------- ------------------ 14/26 [aiohappyeyeballs]
#       Successfully uninstalled aiohappyeyeballs-2.4.4
#    --------------------- ------------------ 14/26 [aiohappyeyeballs]
#    ----------------------- ---------------- 15/26 [watchfiles]
#    ------------------------ --------------- 16/26 [requests-oauthlib]
#    --------------------- ----------- 17/26 [opentelemetry-semantic-conventions]
#    --------------------- ----------- 17/26 [opentelemetry-semantic-conventions]
#    --------------------- ----------- 17/26 [opentelemetry-semantic-conventions]
#    --------------------- ----------- 17/26 [opentelemetry-semantic-conventions]
#    --------------------- ----------- 17/26 [opentelemetry-semantic-conventions]
#    --------------------- ----------- 17/26 [opentelemetry-semantic-conventions]
#    ------------------ -------- 18/26 [opentelemetry-exporter-otlp-proto-common]
#    ----------------------------- ---------- 19/26 [build]
#   Attempting uninstall: aiohttp
#    ----------------------------- ---------- 19/26 [build]
#     Found existing installation: aiohttp 3.11.10
#    ----------------------------- ---------- 19/26 [build]
#    ------------------------------ --------- 20/26 [aiohttp]
#     Uninstalling aiohttp-3.11.10:
#    ------------------------------ --------- 20/26 [aiohttp]
#       Successfully uninstalled aiohttp-3.11.10
#    ------------------------------ --------- 20/26 [aiohttp]
#    ------------------------------ --------- 20/26 [aiohttp]
#    ------------------------------ --------- 20/26 [aiohttp]
#    ------------------------------ --------- 20/26 [aiohttp]
#    ------------------------------ --------- 20/26 [aiohttp]
#    ------------------------------ --------- 20/26 [aiohttp]
#    ------------------------------ --------- 20/26 [aiohttp]
#    ------------------------------ --------- 20/26 [aiohttp]
#    ------------------------------ --------- 20/26 [aiohttp]
#    -------------------------------- ------- 21/26 [opentelemetry-sdk]
#    -------------------------------- ------- 21/26 [opentelemetry-sdk]
#    -------------------------------- ------- 21/26 [opentelemetry-sdk]
#    -------------------------------- ------- 21/26 [opentelemetry-sdk]
#    -------------------------------- ------- 21/26 [opentelemetry-sdk]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    --------------------------------- ------ 22/26 [kubernetes]
#    ----------------------------------- ---- 23/26 [tokenizers]
#    ----------------------------------- ---- 23/26 [tokenizers]
#    -------------------------- -- 24/26 [opentelemetry-exporter-otlp-proto-grpc]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    -------------------------------------- - 25/26 [chromadb]
#    ---------------------------------------- 26/26 [chromadb]
#
# Successfully installed aiohappyeyeballs-2.7.1 aiohttp-3.14.1 aiosignal-1.4.0 build-1.5.0 chromadb-1.5.9 durationpy-0.10 googleapis-common-protos-1.75.0 httptools-0.8.0 importlib-resources-7.1.0 kubernetes-36.0.2 mmh3-5.2.1 oauthlib-3.3.1 onnxruntime-1.27.0 opentelemetry-api-1.43.0 opentelemetry-exporter-otlp-proto-common-1.43.0 opentelemetry-exporter-otlp-proto-grpc-1.43.0 opentelemetry-proto-1.43.0 opentelemetry-sdk-1.43.0 opentelemetry-semantic-conventions-0.64b0 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 pyyaml-6.0.3 requests-oauthlib-2.0.0 tokenizers-0.23.1 watchfiles-1.2.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 6.0.7 requires ipython!=8.17.1,<9.0.0,>=8.13.0; python_version > "3.8", but you have ipython 9.13.0 which is incompatible.
# spyder 6.0.7 requires jedi<0.20.0,>=0.17.2, but you have jedi 0.20.0 which is incompatible.

# %%
import chromadb

client = chromadb.Client()
collection = client.create_collection(name="my_collection")

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids = ['id1', 'id2']
)
# Out:
# C:\Users\hp\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████| 79.3M/79.3M [00:37<00:00, 2.21MiB/s]

# %%
all_docs = collection.get()
all_docs
# Out:
# {'ids': ['id1', 'id2'],
#  'embeddings': None,
#  'documents': ['This document is about New York',
#   'This document is about Delhi'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None, None]}

# %%
documents = collection.get(ids=["id1"])
documents
# Out:
# {'ids': ['id1'],
#  'embeddings': None,
#  'documents': ['This document is about New York'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [None]}

# %%
results = collection.query(
    query_texts=['Query is about brooklyn bridge'],
    n_results=2
)
results
# Out:
# {'ids': [['id1', 'id2']],
#  'embeddings': None,
#  'documents': [['This document is about New York',
#    'This document is about Delhi']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None, None]],
#  'distances': [[1.0953426361083984, 1.5711725950241089]]}

# %%
collection.delete(ids=all_docs['ids'])
collection.get()
# Out:
# {'ids': [],
#  'embeddings': None,
#  'documents': [],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': []}

# %%
collection.add(
    documents=[
        "This document is about New York",
        "This document is about Delhi"
    ],
    ids=["id3", "id4"],
    metadatas=[
        {"url": "https://en.wikipedia.org/wiki/New_York_City"},
        {"url": "https://en.wikipedia.org/wiki/New_Delhi"}
    ]
)

# %%
results = collection.query(
    query_texts=["Query is about taj mahal"],
    n_results=2
)
results
# Out:
# {'ids': [['id4', 'id3']],
#  'embeddings': None,
#  'documents': [['This document is about Delhi',
#    'This document is about New York']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'url': 'https://en.wikipedia.org/wiki/New_Delhi'},
#    {'url': 'https://en.wikipedia.org/wiki/New_York_City'}]],
#  'distances': [[1.2650368213653564, 1.665052890777588]]}
