# %%
pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-1.1.3-py3-none-any.whl.metadata (2.9 kB)
# Collecting groq<1.0.0,>=0.30.0 (from langchain-groq)
#   Downloading groq-0.37.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\users\hp\anaconda3\lib\site-packages (from langchain-groq) (1.4.8)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hp\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\hp\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.4)
# Requirement already satisfied: sniffio in c:\users\hp\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\hp\anaconda3\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.7)
# Requirement already satisfied: certifi in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.9.7)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (9.0.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\hp\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.32.3)
# Requirement already satisfied: websockets>=15.0 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\hp\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.3.0)
# Downloading langchain_groq-1.1.3-py3-none-any.whl (20 kB)
# Downloading groq-0.37.1-py3-none-any.whl (137 kB)
# Installing collected packages: groq, langchain-groq
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    -------------------- ------------------- 1/2 [langchain-groq]
#    ---------------------------------------- 2/2 [langchain-groq]
#
# Successfully installed groq-0.37.1 langchain-groq-1.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
     model_name="llama-3.3-70b-versatile"
)

response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.
